# %%
import numpy as np
import matplotlib as plt
import pandas as pd
import sklearn as sk
from gensim.models import Word2Vec
import json

# %%
data_symptoms = pd.read_csv(r"E:\veda-ai\data\disease_and_symptoms\dataset.csv")
data_symptom_desc = pd.read_csv(r"E:\veda-ai\data\disease_and_symptoms\symptom_Description.csv")
data_precautions = pd.read_csv(r"E:\veda-ai\data\disease_and_symptoms\symptom_precaution.csv")

# %%
data_symptoms
# Out:
#                                       Disease             Symptom_1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3                  Symptom_4  \
# ...

# %%
data_symptom_desc
# Out:
#                                     Disease  \
# 0                             Drug Reaction
# 1                                   Malaria
# 2                                   Allergy
# 3                            Hypothyroidism
# 4                                 Psoriasis
# 5                                      GERD
# 6                       Chronic cholestasis
# 7                               hepatitis A
# 8                           Osteoarthristis
# 9   (vertigo) Paroymsal  Positional Vertigo
# 10                             Hypoglycemia
# 11                                     Acne
# 12                                 Diabetes
# 13                                 Impetigo
# 14                             Hypertension
# 15                      Peptic ulcer diseae
# 16             Dimorphic hemorrhoids(piles)
# 17                              Common Cold
# 18                              Chicken pox
# 19                     Cervical spondylosis
# ...

# %%
file_cont = json.load(open(r"E:\veda-ai\scraped_health_topics.json"))

# %%
# file_cont

# %%
summaries = [x['summary'] for x in file_cont]

# %%
summaries[0]
# Out:
# '   An aneurysm is a bulge or "ballooning" in the wall of an artery. Arteries are blood vessels that carry oxygen-rich blood from the heart to other parts of the body. If an aneurysm grows large, it can burst and cause dangerous bleeding or even death. Most aneurysms are in the aorta, the main artery that runs from the heart through the chest and abdomen. There are two types of aortic aneurysm: Most aneurysms are found during tests done for other reasons. Some people are at high risk for aneurysms. It is important for them to get screening, because aneurysms can develop and become large before causing any symptoms. Screening is recommended for people between the ages of 65 and 75 if they have a family history, or if they are men who have smoked. Doctors use imaging tests to find aneurysms. Medicines and surgery are the two main treatments. NIH: National Heart, Lung, and Blood Institute'

# %%
def cleaning_text(content: list):
    cleaned_text = []
    
    
    for text in content:
        lower = text.lower()
                
                # Replacing the repeating pattern of &#039;
        pattern_remove = lower.replace("&#039;", "")
                
                # Removing all the special Characters
        special_remove = pattern_remove.replace(r'[^\w\d\s]',' ')
                
                # Removing all the non ASCII characters
        ascii_remove = special_remove.replace(r'[^\x00-\x7F]+',' ')
                
                # Removing the leading and trailing Whitespaces
        whitespace_remove = ascii_remove.replace(r'^\s+|\s+?$','')
                
                # Replacing multiple Spaces with Single Space
        multiw_remove = whitespace_remove.replace(r'\s+',' ')
                
                # Replacing Two or more dots with one
        dataframe = multiw_remove.replace(r'\.{2,}', ' ')
            
        cleaned_text.append(dataframe.replace('"',''))
    
    return cleaned_text

# %%
cleaned_summary = cleaning_text(summaries)

# %%
cleaned_summary[0]
# Out:
# '   an aneurysm is a bulge or ballooning in the wall of an artery. arteries are blood vessels that carry oxygen-rich blood from the heart to other parts of the body. if an aneurysm grows large, it can burst and cause dangerous bleeding or even death. most aneurysms are in the aorta, the main artery that runs from the heart through the chest and abdomen. there are two types of aortic aneurysm: most aneurysms are found during tests done for other reasons. some people are at high risk for aneurysms. it is important for them to get screening, because aneurysms can develop and become large before causing any symptoms. screening is recommended for people between the ages of 65 and 75 if they have a family history, or if they are men who have smoked. doctors use imaging tests to find aneurysms. medicines and surgery are the two main treatments. nih: national heart, lung, and blood institute'

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import contractions
import string
import re
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')

def filter_stop_words(text):
    lemmatizer = WordNetLemmatizer()
    stop_words = set(stopwords.words('english'))

    #This normalizes the texts by converting all the words into normal form(example, couldn't to could not)
    text= contractions.fix(text)

    #to remove the urls and normalizing the texts by removing the accent letters.
    #This also converts the text into ascii and then analyzes it
    # text = unidecode.unidecode(text)

    #Removes the punctuations
    text = text.translate(str.maketrans('', '', string.punctuation))

    #tokenizes the words
    tokens = word_tokenize(text)

    text = [word for word in tokens if word not in stop_words and len(word)>2 or re.match(r"-?\d{1,3}(,\d{3})*(\.\d+)?|\d+(\.\d+)?",word)]

    lemmatized_tokens = [lemmatizer.lemmatize(text) for text in text]
    return lemmatized_tokens
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\adity\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\adity\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\adity\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\adity\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
new_summary = []
words = []
for text in cleaned_summary:
    new_summary.append(filter_stop_words(text))

# %%
new_summary[0]
# Out:
# ['aneurysm',
#  'bulge',
#  'ballooning',
#  'wall',
#  'artery',
#  'artery',
#  'blood',
#  'vessel',
#  'carry',
#  'oxygenrich',
#  'blood',
#  'heart',
#  'part',
#  'body',
#  'aneurysm',
#  'grows',
#  'large',
#  'burst',
#  'dangerous',
#  'bleeding',
#  'even',
#  'death',
#  'aneurysm',
#  'aorta',
#  'main',
#  'artery',
#  'run',
#  'heart',
#  'chest',
#  'abdomen',
#  'two',
#  'type',
#  'aortic',
#  'aneurysm',
#  'aneurysm',
#  'found',
#  'test',
#  'done',
#  'reason',
#  'people',
#  'high',
#  'risk',
#  'aneurysm',
#  'important',
#  'get',
#  'screening',
#  'aneurysm',
#  'develop',
#  'become',
#  'large',
#  'causing',
#  'symptom',
#  'screening',
#  'recommended',
#  'people',
#  'age',
#  '65',
#  '75',
#  'family',
#  'history',
#  'men',
#  'smoked',
#  'doctor',
#  'use',
#  'imaging',
#  'test',
#  'find',
#  'aneurysm',
#  'medicine',
#  'surgery',
#  'two',
#  'main',
#  'treatment',
#  'nih',
#  'national',
#  'heart',
#  'lung',
#  'blood',
# ...

# %%
model = Word2Vec(sentences=new_summary,
                 vector_size=100,
                 window = 5,
                 min_count=0,
                 workers=4,
                 seed=24)

# %%
word_vectors = model.wv
#word_vectors.save('word2vec_model.kv')

# %%
from gensim.models import KeyedVectors

load_model = KeyedVectors.load('word2vec_model.kv')

already_seen_wd = []
map_wd_and_vec = {}


for li_words in new_summary:
    for word in li_words:
        if word not in already_seen_wd:
            map_wd_and_vec[word] = np.mean(word_vectors[word])
            already_seen_wd.append(word)
already_seen_wd = []

# %%
#map_wd_and_vec

# %%
#mapping the words and vectors into a dictionary
word_vec_li = []
new_summary_embedds = []

for li_word in new_summary:
    for word in li_word:
        word_vec_li.append(np.mean(model.wv[word]))
    new_summary_embedds.append(np.array(word_vec_li).reshape(1,-1))
    word_vec_li = []

# %%
new_summary_embedds[0].shape
# Out:
# (1, 79)

# %%
# validating if the words are mapped correctly
for word, vec in map_wd_and_vec.items():
    for vectors in new_summary_embedds:
       if vec in vectors:
            print(True)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...

# %%
doc_with_embed = file_cont
index = 0

for index in range(len(doc_with_embed)):
    doc_with_embed[index]['summary'] = new_summary_embedds[index]

print(doc_with_embed[0])
# Out:
# {'ID': 1, 'body_location_system_topic': 'Blood, Heart and Circulation', 'curr_topic': 'Aortic Aneurysm', 'summary': array([[0.00832369, 0.00087784, 0.00037854, 0.00321687, 0.00453054,
#         0.00453054, 0.030144  , 0.00377811, 0.01013854, 0.00205712,
#         0.030144  , 0.0112829 , 0.0225795 , 0.03458234, 0.00832369,
#         0.00943354, 0.01148267, 0.00171699, 0.00289065, 0.01041693,
#         0.00777063, 0.00242201, 0.00832369, 0.00182143, 0.00723742,
#         0.00453054, 0.00394237, 0.0112829 , 0.00573004, 0.00778824,
#         0.01681262, 0.02962796, 0.00061791, 0.00832369, 0.00832369,
#         0.00862335, 0.02763585, 0.00801861, 0.00377316, 0.03369872,
#         0.01311929, 0.02568601, 0.00832369, 0.02201141, 0.0334096 ,
#         0.00440773, 0.00832369, 0.01141233, 0.0126036 , 0.01148267,
#         0.00583128, 0.03171331, 0.00440773, 0.0021963 , 0.03369872,
#         0.01863284, 0.00192252, 0.0018886 , 0.011087  , 0.00970593,
# ...

# %%
import faiss

#indexing the documents function

def index_docs_Euclidian(doc_vec_list:list, doc_with_embed:dict):
    # as the index documents always maintain the order in which they have inserted so we can get index and then the metadata by just querying it. 
    for docs in range(len(doc_vec_list)):    
        dimension = doc_vec_list[docs].shape[1]
        index = faiss.IndexFlatL2(dimension)
        index.add(doc_vec_list[docs])
        print(f'Document{docs} of topic:{doc_with_embed[docs]['curr_topic']} is indexed')
    return index

# %%
#indexing documents here

index_faiss = index_docs_Euclidian(new_summary_embedds, doc_with_embed)
# Out:
# Document0 of topic:Aortic Aneurysm is indexed
# Document1 of topic:Aortic Aneurysm is indexed
# Document2 of topic:Blood is indexed
# Document3 of topic:Acute Lymphocytic Leukemia is indexed
# Document4 of topic:Acute Lymphocytic Leukemia is indexed
# Document5 of topic:Acute Myeloid Leukemia is indexed
# Document6 of topic:Acute Myeloid Leukemia is indexed
# Document7 of topic:Atrial Fibrillation is indexed
# Document8 of topic:Acute Lymphocytic Leukemia is indexed
# Document9 of topic:Acute Myeloid Leukemia is indexed
# Document10 of topic:Heel Injuries and Disorders is indexed
# Document11 of topic:Dwarfism is indexed
# Document12 of topic:Knee Injuries and Disorders is indexed
# Document13 of topic:Limb Loss is indexed
# Document14 of topic:Anatomy is indexed
# Document15 of topic:Ankle Injuries and Disorders is indexed
# Document16 of topic:Ankylosing Spondylitis is indexed
# Document17 of topic:Knee Injuries and Disorders is indexed
# ...

# %%
# Now through index_faiss instance we can query to find similar items by queries.
query = ["Weakness or feeling tired, Easy bruising or bleeding, Petechiae, which are tiny red dots under the skin. They are caused by bleeding. Shortness of breath, Weight loss or loss of appetite Pain in the bones or stomach, Pain or feeling of fullness below the ribs"]

# %%
model.save('word2vec_model')

# %%
import gensim
loaded_model = Word2Vec.load('word2vec_model')

# %%
cleaned_q = cleaning_text(query)
clean_q = filter_stop_words(cleaned_q[0])

# %%
clean_q = [clean_q]

# %%
len(clean_q)
# Out:
# 1

# %%
loaded_model.build_vocab(clean_q, update=True)

# %%
loaded_model.train(clean_q, total_examples=loaded_model.corpus_count, epochs=model.epochs)
# Out:
# (20, 130)

# %%
loaded_model.wv['fullness']
# Out:
# array([ 8.4872833e-03,  4.4037933e-03, -1.1492464e-02, -3.5949664e-03,
#        -4.9687638e-03, -7.4866922e-03, -6.1836862e-03,  3.1376625e-03,
#        -4.5163836e-03,  1.0560392e-02,  9.2136012e-03,  1.0592405e-02,
#        -4.9943262e-04,  2.2922554e-03, -8.3824592e-03, -6.0019959e-03,
#        -8.6019952e-03, -1.6417224e-03,  6.0796933e-03,  3.3843203e-03,
#        -7.8773117e-03,  3.1459646e-03,  1.2538699e-03,  7.8816814e-03,
#        -4.7750035e-03, -3.3855105e-03, -9.8337829e-03,  6.8636634e-03,
#        -2.0828980e-03, -7.1983790e-04, -3.6369790e-03,  1.8661070e-05,
#        -1.0798509e-02, -1.0965866e-02, -5.0472147e-03, -6.3392712e-05,
#        -6.4135920e-03, -2.1849694e-03,  6.9866744e-03, -8.3315447e-03,
#         6.0387621e-05,  7.4312985e-03, -1.3821492e-03,  7.9537462e-03,
#         3.7045714e-03,  2.7784803e-03,  1.6825147e-03, -6.1120815e-03,
#         6.4780712e-03,  5.4805027e-03,  2.9948840e-03,  4.2186412e-03,
# ...

# %%
query_vec_step1 = np.array([np.mean(loaded_model.wv[word]) for word in clean_q[0]]).reshape(1, -1)
query_vec = np.vstack(query_vec_step1)

# %%
query_vec
# Out:
# array([[ 8.6949096e-04,  1.5524237e-03,  8.0505310e-04,  6.7088078e-03,
#          2.3523108e-03,  1.0588050e-02,  6.1680900e-04,  1.6657929e-03,
#          6.9229458e-03,  5.6131958e-04,  1.8108761e-02,  1.1328549e-02,
#          1.0588050e-02,  1.4660857e-03,  9.0295030e-03,  5.9600710e-03,
#          1.4418495e-02,  1.4418495e-02,  1.0150053e-03,  2.6362497e-02,
#          2.3257427e-02,  6.0893390e-03,  2.6362497e-02,  1.5524237e-03,
#         -8.7700522e-05,  2.5975972e-04]], dtype=float32)

# %%
distance, index_of_doc = index_faiss.search(query_vec, k=2)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 distance, index_of_doc = index_faiss.search(query_vec, k=2)
#
# File E:\veda-ai\env\Lib\site-packages\faiss\class_wrappers.py:329, in handle_Index.<locals>.replacement_search(self, x, k, params, D, I)
#     327 n, d = x.shape
#     328 x = np.ascontiguousarray(x, dtype='float32')
# --> 329 assert d == self.d
#     331 assert k > 0
#     333 if D is None:
#
# AssertionError:

# %% [markdown]
# ## --------WORD2VEC model fails in generating new vector embeeddings.------------------

# %%
# using bert model
import random
import torch
from transformers import BertTokenizer, BertModel
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Load BERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# E:\veda-ai\env\Lib\site-packages\huggingface_hub\file_download.py:147: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\adity\.cache\huggingface\hub\models--bert-base-uncased. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# ...

# %%
# Apply BERT tokenization to the 'summary' column
def tokenize_summary(text):
    encoding = tokenizer.batch_encode_plus(
        [text],                 # List of input texts
        padding=True,           # Pad to the maximum sequence length
        truncation=True,        # Truncate to the maximum sequence length
        return_tensors='pt',    # Return PyTorch tensors
        add_special_tokens=True # Add CLS and SEP tokens
    )
    
    input_ids = encoding['input_ids'].tolist()[0]  # Get token IDs as a list
    attention_mask = encoding['attention_mask'].tolist()[0]  # Get attention mask as a list
    
    return input_ids, attention_mask

# %%
tokenized_summary_list = []
attention_mask_list = []

for single_summary in cleaned_summary:
    input_ids, attention_mask = tokenize_summary(single_summary)
    tokenized_summary_list.append(input_ids)
    attention_mask_list.append(attention_mask)

# %%
tokenized_summary_list[0]
# Out:
# [101,
#  2019,
#  2019,
#  11236,
#  7274,
#  2213,
#  2003,
#  1037,
#  23708,
#  2030,
#  13212,
#  2075,
#  1999,
#  1996,
#  2813,
#  1997,
#  2019,
#  16749,
#  1012,
#  28915,
#  2024,
#  2668,
#  6470,
#  2008,
#  4287,
#  7722,
#  1011,
#  4138,
#  2668,
#  2013,
#  1996,
#  2540,
#  2000,
#  2060,
#  3033,
#  1997,
#  1996,
#  2303,
#  1012,
#  2065,
#  2019,
#  2019,
#  11236,
#  7274,
#  2213,
#  7502,
#  2312,
#  1010,
#  2009,
#  2064,
#  6532,
#  1998,
#  3426,
#  4795,
#  9524,
#  2030,
#  2130,
#  2331,
#  1012,
#  2087,
#  2019,
#  11236,
#  7274,
#  5244,
#  2024,
#  1999,
#  1996,
#  20118,
#  13320,
#  1010,
#  1996,
#  2364,
#  16749,
#  2008,
#  3216,
#  2013,
#  1996,
#  2540,
#  2083,
#  1996,
#  3108,
#  1998,
#  13878,
#  1012,
#  2045,
#  2024,
#  2048,
#  4127,
#  1997,
#  20118,
#  28228,
#  2278,
#  2019,
#  11236,
#  7274,
#  2213,
#  1024,
#  2087,
#  2019,
#  11236,
#  7274,
#  5244,
#  2024,
#  2179,
#  2076,
#  5852,
#  2589,
#  2005,
#  2060,
# ...

# %%
# Define a function to apply BERT to tokenized input
def generate_embeddings_from_tokens(input_ids, attention_mask):
    input_ids_tensor = torch.tensor([input_ids])       # Convert list to tensor
    attention_mask_tensor = torch.tensor([attention_mask])  # Convert list to tensor

    # Generate embeddings using BERT
    with torch.no_grad():
        outputs = model(input_ids_tensor, attention_mask=attention_mask_tensor)
        word_embeddings = outputs.last_hidden_state.squeeze(0)  # Shape: (sequence_length, hidden_size)

    return word_embeddings.mean(dim=0).numpy()

# %%
embedding_of_summary = []
for iter_for_list in range(len(tokenized_summary_list)):
    embedding_of_summary.append(generate_embeddings_from_tokens(input_ids = tokenized_summary_list[iter_for_list], 
                                                                attention_mask = attention_mask_list[iter_for_list])
                               )

# %%
embedding_of_summary[0]
# Out:
# array([-1.30264759e-01,  1.85986832e-01,  1.51899680e-01, -2.02770367e-01,
#         6.70748889e-01, -1.25139281e-02,  1.31675899e-01,  6.85009420e-01,
#         1.33807911e-02, -2.95006096e-01, -2.00343773e-01, -3.22098136e-01,
#        -6.37092739e-02,  2.17505962e-01, -5.78583740e-02,  4.41036463e-01,
#         5.76588750e-01, -1.41647840e-02, -2.77748138e-01,  4.45144147e-01,
#         2.30716854e-01, -1.78170681e-01,  3.11030149e-02,  6.88839316e-01,
#         3.12703162e-01, -2.28266031e-01, -1.42576829e-01,  1.06855862e-01,
#        -6.83308020e-02, -4.85952318e-01,  4.74349380e-01,  1.42114207e-01,
#        -1.61549523e-01, -2.78429270e-01, -5.83384186e-02,  1.12745367e-01,
#        -9.96120498e-02, -3.22031289e-01, -5.45020588e-02,  2.97435820e-02,
#        -6.20869219e-01, -2.83585876e-01, -2.04762146e-01,  1.10581428e-01,
#        -6.40034825e-02, -9.82986689e-02,  4.86224473e-01,  3.41250934e-02,
# ...
